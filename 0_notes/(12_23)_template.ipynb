# %% [markdown]
# ## Video-12 (ch10): Render Templates
# ---
# ---

# %% [markdown]
# - Create a application named course
# - create folder on course application in following structure
# - course
#     - templates
#         - course
#             - index.html
#             - django.html

# %% [markdown]
# 📂course/urls.py
#
# ---
# ```python
#
#
# from django.urls import path
# from .views import learn_django, learn_django_template
#
# urlpatterns = [
#     path('dj/', learn_django),
#     path('dj_temp/', learn_django_template),
# ]
#
# ```
#
# 📂course/views.py
#
# ---
# ```python
#
# from django.shortcuts import render
# from django.http import HttpResponse
#
# def learn_django(req):
#     html = '<h1>Hello Django from Course App</h1>'
#     return HttpResponse(html)
#
# def learn_django_template(request):
#     # render(request, template_name, context = dict_name, content_type = MIME_TYPE, status = None, using = None)
#     return render(request, 'course/django.html')
# ```

# %% [markdown]
# ## Video-13 (ch11): Render Dynamic Template
# ---
# ---

# %% [markdown]
# 📂course/urls.py
#
# ---
# ```python
#
# from django.urls import path
# from .views import learn_django
#
# urlpatterns = [
#     path('dj/', learn_django),
# ]
#
# ```
#
# 📂course/views.py
#
# ---
# ```python
#
# from django.shortcuts import render
#
#
# def learn_django(request):
#     seats = 10
#     coursedetail = {'cname': 'Django', 'version': 5.1, 'seats': seats}
#     # return render(request, 'course/django.html', context=coursedetail)
#     # return render(request, 'course/django.html', {'cname': 'Django', 'version': 5.1, 'seats': seats})
#     return render(request, 'course/django.html', coursedetail)
#
# ```
#
# 📂course/templates/course/django.html
#
# ---
# ```html
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
# </head>
# <body>
#     <h1>Hello {{cname}} {{version}}</h1>
#     <h2>Seats : {{seats}}</h2>
# </body>
# </html>
#
# ```

# %% [markdown]
# ## Video-14 (ch12): Django Template Language
# ---
# ---

# %% [markdown]
# 📂course/views.py
#
# ---
# ```python
#
# from django.shortcuts import render
# from datetime import datetime
#
# # Example 1.1 - Variable
# def learn_django(request):
#     return render(request, 'course/django.html', context={'name': 'Django'})
#
# # Example 1.2 - Variable
# def learn_django(request):
#     name = 'Django'
#     duration = '4 months'
#     seats = 10
#     course_details = {'nm': name, 'du': duration, 'st': seats}
#     return render(request, 'course/django.html', course_details)
#
# # Example 2 - Filter
# def learn_django(request):
#     return render(request, 'course/django.html', context={'name': 'Django', 'desc': 'Django is awsome web framework'})
#
# # Example 3 - Date and Time
# def learn_django(request):
#     d = datetime.now()
#     return render(request, 'course/django.html', context={'dt': d})
#
# # Example 4 - Float Format
# def learn_django(request):
#     return render(request, 'course/django.html', context={'p1': 56.24321, 'p2': 56.000, 'p3': 56.37000})
#
# # Example 5.1 - If Tag
# def learn_django(request):
#     # (nm = '' ==> False ) (nm = 'ldlfs' ==> True)
#     return render(request, 'course/django.html', context={'nm': True})
#
# # Example 5.2 - If Tag
# def learn_django(request):
#     return render(request, 'course/django.html', context={'nm': 'Django', 'st': 5})
#
# # Example 6 - For loop
# def learn_django(request):
#     students = {'names': ['Rahul', 'Sonam', 'Raj', 'Anu']}
#     return render(request, 'course/django.html', context=students)
#
# # Example 7 - Complex data
# def learn_django(request):
#     stu = {'stu1': {'name': 'Rahul', 'roll': 101},
#            'stu2': {'name': 'Sonam', 'roll': 102},
#            'stu3': {'name': 'Raj', 'roll': 103},
#            'stu4': {'name': 'Anu', 'roll': 104},
#            }
#     students = {'students': stu}
#     return render(request, 'course/django.html', context=students)
#
#
# # Example 8 - Complex data
# def learn_django(request):
#     student = {'name': 'Rahul', 'roll': 101}
#     return render(request, 'course/django.html', context={'student': student})
#
#
# # Example 9 - Complex data
# def learn_django(request):
#     stu = {'stu1': {'name': 'Rahul', 'roll': 101},
#            'stu2': {'name': 'Sonam', 'roll': 102},
#            'stu3': {'name': 'Raj', 'roll': 103},
#            'stu4': {'name': 'Anu', 'roll': 104},
#            }
#     return render(request, 'course/django.html', {'students':stu})
#
# ```

# %% [markdown]
# 📂course/templates/course/django.html
#
# ---
# ```html
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
# </head>
# <body>
#     <h1>Hello Django Template Language (DTL)</h1>
#     <h2>Example 1.1: Variable</h2>
#     <h3>Name: {{name}}</h3>
#
#
#     <h2>Example 1.2: Variable</h2>
#     <h3>Name: {{nm}}</h3>
#     <h3>Duration: {{du}}</h3>
#     <h3>Seats: {{st}}</h3>
#
#
#     <h2>Example 2: Filters</h2>
#     <h3>Name: {{name}}</h3>
#     <h3>Upper: {{name|upper}}</h3>
#     <h3>Lower: {{name|lower}}</h3>
#     <h3>Default: {{name|default:'nothing'}}</h3>
#     <h3>Length: {{name|length}}</h3>
#     <h3>Slice: {{name|slice:"2"}}</h3>
#     <h3>Truncate Char: {{name|truncatechars:3}}</h3>
#
#     <h3>Desc: {{desc}}</h3>
#     <h3>Truncate word: {{desc|truncatewords:3}}</h3>
#     <h3>Upper & Truncate word: {{desc|upper|truncatewords:3}}</h3>
#
#
#     <h2>Example 3: Date And Time</h2>
#     <h3>{{dt}}</h3>     <!-- Feb. 14, 2026, 7:57 p.m. -->
#     <h3>{{dt|date}}</h3>    <!-- Feb. 14, 2026 -->
#     <h3>{{dt|date:'D d M Y'}}</h3>     <!-- Sat 14 Feb 2026 -->
#     <h3>{{dt|time}}</h3>     <!-- 8:01 p.m. -->
#     <h3>{{dt|time:'H:i'}}</h3>    <!-- 20:01 -->
#     <h3>{{dt|date:'SHORT_DATE_FORMAT'}}</h3>     <!-- 02/14/2026 -->
#     <h3>{{dt|time:'TIME_FORMAT'}}</h3>     <!-- 8:04 p.m. -->
#
#
#     <h2>Example 4: Float Format</h2>
#     <h3>{{p1}}</h3>
#     <h3>{{p2}}</h3>
#     <h3>{{p3}}</h3>
#
#     <h3>{{p1|floatformat}}</h3>
#     <h3>{{p2|floatformat}}</h3>
#     <h3>{{p3|floatformat}}</h3>
#
#     <h3>{{p1|floatformat:3}}</h3>
#     <h3>{{p1|floatformat:0}}</h3>
#
#     <h3>{{p1|floatformat:-3}}</h3>
#     <h3>{{p2|floatformat:-3}}</h3>
#     <h3>{{p3|floatformat:-3}}</h3>
#
#
#     <h2>Example 5.1: If tag</h2>
#     {% if nm %}
#         <h3>Hello If Tag</h3>
#     {% endif %}
#
#
#     <h2>Example 5.2: If tag</h2>
#     {% if nm and st %}
#         <h3>Name: {{nm}} Seats: {{st}}</h3>
#     {% endif %}
#
#     {% if nm or st %}
#         <h3>Name: {{nm}} Seats: {{st}}</h3>
#     {% endif %}
#
#     {% if not nm %}
#         <h3>Name: {{nm}} Seats: {{st}}</h3>
#     {% endif %}
#
#     {% if nm == 'Django' %}
#         <h3>Name: {{nm}} Seats: {{st}}</h3>
#     {% endif %}
#
#     {% if nm == 'Django' and st == 5 %}
#         <h3>Name: {{nm}} Seats: {{st}}</h3>
#     {% endif %}
#
#     {% if nm|length >= 4 %}
#         <h3>Name: {{nm}} Seats: {{st}}</h3>
#     {% endif %}
#
#     {% if nm == 'Django' %}
#         <h3>Name: {{nm}} Seats: {{st}}</h3>
#     {% else %}
#         <h3>Name: Guest</h3>
#     {% endif %}
#
#     {% if nm == 'Django' %}
#         <h3>Name: {{nm}} Seats: {{st}}</h3>
#     {% elif nm == 'Python' %}
#         <h3>Name: {{nm}} Seats: {{st}}</h3>
#     {% else %}
#         <h3>Name: Guest</h3>
#     {% endif %}
#
#
#     <h2>Example 6: For Loop</h2>
#     <ul>
#         {% for name in names %}
#             <li>{{name}}</li>
#         {% endfor %}
#     </ul>
#     <hr>
#
#     <ul>
#         {% for name in names reversed %}
#             <li>{{name}}</li>
#         {% endfor %}
#     </ul>
#     <hr>
#
#     <ul>
#         {% for name in names reversed %}
#             <li>{{name}}</li>
#         {% empty %}
#             <h3>Empty List</h3>
#         {% endfor %}
#     </ul>
#     <hr>
#
#     <ul>
#         {% for name in names reversed %}
#             <li>{{forloop.counter}} {{name}}</li>
#         {% endfor %}
#     </ul>
#
#
#     <h2>Example 7: Complex Data</h2>
#     <h3>{{students}}</h3>
#     <h3>{{students.stu1}}</h3>
#     <h3>{{students.stu1.name}}</h3>
#     <h3>{{students.stu1.roll}}</h3>
#
#
#     <h2>Example 8</h2>
#     <h3>{{student}}</h3>
#     {% for key, value in student.items %}
#         {{key}} - {{value}} <br>
#     {% endfor %}
#
#
#     <h2>Example 9</h2>
#     {% for key, value in students.items %}
#         {{key}} - {{value}} <br>
#         {% for k, v in value.items %}
#             {{k}} - {{v}} <br>
#         {% endfor %}
#     {% endfor %}
#
#     {% for key, value in students.items %}
#         {% for k, v in value.items %}
#             {{forloop.parentloop.counter}} - {{k}} - {{v}} <br>
#         {% endfor %}
#     {% endfor %}
#
# </body>
# </html>
#
# ```

# %% [markdown]
# ## Video-15 (ch13): Django Static Files CSS, JS and Image
# ---
# ---

# %% [markdown]
# **Folder and File structure to add static files:**
# Application name course
#
# - course
#     - static
#         - css
#             - style.css
#         - images
#             - pic1.png
#         - js
#             - scripts.js

# %% [markdown]
# 📂course/templates/course/django.html
#
# ---
# ```html
#
# <!DOCTYPE html>
# {% load static %}
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <link rel="stylesheet" href="{% static 'course/css/style.css' %}">
#     <title>Document</title>
# </head>
# <body>
#     <h1>{{nm}} with Static Files</h1>
#     <img src="{% static 'course/images/pic1.png' %}" width="200px" alt="Django">
#
#     <img src="{% get_static_prefix %}course/images/pic1.png" width="300px" alt="Django">
#
#     <form action="">
#         <input type="button" value="Click Me" onclick="disp()">
#     </form>
#
#     <script src="{% static 'course/js/scripts.js' %}"></script>
# </body>
# </html>
#
# ```

# %% [markdown]
# ## Video-16 (ch14): Django Template Inheritance
# ---
# ---

# %% [markdown]
# **Project Folder Structure:**
#
# - ch14
#     - core
#         - templates
#             - core
#                 - base.html
#                 - home.html
#     - course
#         - templates
#             - course
#                 - django.html
#                 - python.html

# %% [markdown]
# 📂base.html
#
# ---
# ```html
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>{% block title %} {% endblock title %}</title>
# </head>
# <body>
#     <ul>
#         <li>Home</li>
#         <li>Django</li>
#         <li>Python</li>
#     </ul>
#     {% block hero %}{% endblock hero %}
#
#     {% block content %}{% endblock content %}
#
#     {% block footer %}This is Footer{% endblock footer %}
# </body>
# </html>
#
# ```

# %% [markdown]
# 📂home.html
#
# ---
# ```html
#
# {% extends 'core/base.html' %}
#
# {% block title %}Home{% endblock title %}
#
# {% block hero %}
# <h2>Hero Section</h2>
# {% endblock hero %}
#
# {% block content %}
# <h1>Home Page</h1>
# {% endblock content %}
#
# {% block footer %}This is Home Footer{% endblock footer %}
#
# ```

# %% [markdown]
# 📂django.html
#
# ---
# ```html
#
# {% extends 'core/base.html' %}
#
# {% block title %}Django{% endblock title %}
#
# {% block content %}
# <h1>Django Page</h1>
# {% endblock content %}
#
# {% block footer %}{{block.super}} This is Django Footer{% endblock footer %}
#
# ```

# %% [markdown]
# 📂python.html
#
# ---
# ```html
#
# {% extends 'core/base.html' %}
#
# {% block title %}Python{% endblock title %}
#
# {% block content %}
# <h1>Python Page</h1>
# {% endblock content %}
#
# ```

# %% [markdown]
# ## Video-17 (ch15): Django Template Inheritance with Static Files
# ---
# ---

# %% [markdown]
# **Project Folder Structure:**
#
# - ch14
#     - core
#         - templates
#             - core
#                 - base.html
#                 - home.html
#         - static
#             - core
#                 - css
#                     - style.css
#     - course
#         - templates
#             - course
#                 - django.html
#                 - python.html
#         - static
#             - course
#                 - css
#                     - style.css

# %% [markdown]
# 📁base.html
#
# ---
#
# ```html
#
# <!DOCTYPE html>
# {% load static %}
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>{% block title %} {% endblock title %}</title>
#     {% block corecss %}<link rel="stylesheet" href="{% static 'core/css/style.css' %}">{% endblock corecss %}
# </head>
# <body>
#     <ul>
#         <li>Home</li>
#         <li>Django</li>
#         <li>Python</li>
#     </ul>
#     {% block hero %}{% endblock hero %}
#
#     {% block content %}{% endblock content %}
#
#     {% block footer %}This is Footer{% endblock footer %}
# </body>
# </html>
#
# ```

# %% [markdown]
# 📁django.html
#
# ---
#
# ```html
#
# {% extends 'core/base.html' %}
# {% load static %}
#
# {% block title %}Django{% endblock title %}
#
# {% block corecss %}
# {{block.super}}
# <link rel="stylesheet" href="{% static 'course/css/style.css' %}">
# {% endblock corecss %}
#
# {% block content %}
# <h1>Django Page</h1>
# {% endblock content %}
#
# {% block footer %}{{block.super}} This is Django Footer{% endblock footer %}
#
# ```

# %% [markdown]
# ## Video-18 (ch16): Setup Bootstrap with Django
# ---
# ---

# %% [markdown]
# **Similar folder structure like previous.**
#
#
# **1. Adding Bootstrap using cdn link:**
#
# [Bootstrap Docs Link](https://getbootstrap.com/)

# %% [markdown]
# 📁base.html
#
# ---
#
# ```html
#
# <!DOCTYPE html>
# {% load static %}
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>{% block title %} {% endblock title %}</title>
#
#     <!-- Adding bootstrap using cdn link -->
#     <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.3.8/dist/css/bootstrap.min.css" rel="stylesheet" integrity="sha384-sRIl4kxILFvY47J16cr9ZwB07vP4J8+LH7qKQnuqkuIAvNWLzeN8tE5YBujZqJLB" crossorigin="anonymous">
#
#
#     {% block corecss %}<link rel="stylesheet" href="{% static 'core/css/style.css' %}">{% endblock corecss %}
# </head>
# <body>
#     <ul>
#         <li>Home</li>
#         <li>Django</li>
#         <li>Python</li>
#     </ul>
#     {% block hero %}{% endblock hero %}
#
#     {% block content %}{% endblock content %}
#
#     {% block footer %}This is Footer{% endblock footer %}
#
#     <!-- Adding bootstrap using cdn link -->
#     <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.3.8/dist/js/bootstrap.bundle.min.js" integrity="sha384-FKyoEForCGlyvwx9Hj09JcYn3nv7wiPVlz7YYwJrWVcXK/BmnVDxM+D2scQbITxI" crossorigin="anonymous"></script>
# </body>
# </html>
#
# ```

# %% [markdown]
# 📁home.html
#
# ---
#
# ```html
#
# {% extends 'core/base.html' %}
#
# {% block title %}Home{% endblock title %}
#
# {% block hero %}
# <h2>Hero Section</h2>
# {% endblock hero %}
#
# {% block content %}
# <h1>Home Page</h1>
# <button type="button" class="btn btn-primary">Primary</button>
# <button type="button" class="btn btn-secondary">Secondary</button>
# <button type="button" class="btn btn-success">Success</button>
# <button type="button" class="btn btn-danger">Danger</button>
# <button type="button" class="btn btn-warning">Warning</button>
# <button type="button" class="btn btn-info">Info</button>
# <button type="button" class="btn btn-light">Light</button>
# <button type="button" class="btn btn-dark">Dark</button>
#
# <button type="button" class="btn btn-link">Link</button>
# {% endblock content %}
#
# {% block footer %}This is Home Footer{% endblock footer %}
#
# ```

# %% [markdown]
# **2. Adding Bootstrap by Downloading:**
#
# - Go to bootstrap website and go to download option from menubar
# - Click download on Compiled CSS and JS
# - Extract zip
# - copy bootstrap.css and bootstrap.js file from css and js folder
# - paste the files in following ways:
#
# - ch14
#     - core
#         - templates
#             - core
#                 - base.html
#                 - home.html
#         - static
#             - core
#                 - css
#                     - style.css
#                     - bootstrap.css
#                 - js
#                     - bootstrap.js

# %% [markdown]
# 📁base.html
#
# ---
#
# ```html
#
# <!DOCTYPE html>
# {% load static %}
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>{% block title %} {% endblock title %}</title>
#
#     <!-- Adding bootstrap using downloaded file -->
#     <link rel="stylesheet" href="{% static 'core/css/bootstrap.css' %}" >
#
#
#     {% block corecss %}<link rel="stylesheet" href="{% static 'core/css/style.css' %}">{% endblock corecss %}
# </head>
# <body>
#     <ul>
#         <li>Home</li>
#         <li>Django</li>
#         <li>Python</li>
#     </ul>
#     {% block hero %}{% endblock hero %}
#
#     {% block content %}{% endblock content %}
#
#     {% block footer %}This is Footer{% endblock footer %}
#
#     <!-- Adding bootstrap using downloaded file -->
#     <script src="{% static 'core/css/bootstrap.js' %}"></script>
# </body>
# </html>
#
# ```

# %% [markdown]
# **3. Adding Bootstrap using python command:**
#
# [Bootstrap Python Adding Link](https://django-bootstrap5.readthedocs.io/)
#
# - Go to Installation and follow the instruction
# - Now go to Project folder from command prompt
# - Install Bootstrap: `pip install django-bootstrap5`
# - Now go to project's settings.py and  do the followings
#
# ```python
#
# INSTALLED_APPS = [
#     ...
#     'django_bootstrap5',
#     'core',
#     'course',
# ]
#
# ```
# - Go to QuickStart and follow the template adding instruction

# %% [markdown]
# 📁base.html
#
# ---
#
# ```html
#
# <!DOCTYPE html>
# {% load static %}
# {% load django_bootstrap5 %}
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>{% block title %} {% endblock title %}</title>
#
#     <!-- Adding bootstrap python command -->
#     {% bootstrap_css %}
#     {% bootstrap_javascript %}
#
#     {% block corecss %}<link rel="stylesheet" href="{% static 'core/css/style.css' %}">{% endblock corecss %}
# </head>
# <body>
#     <ul>
#         <li>Home</li>
#         <li>Django</li>
#         <li>Python</li>
#     </ul>
#     {% block hero %}{% endblock hero %}
#
#     {% block content %}{% endblock content %}
#
#     {% block footer %}This is Footer{% endblock footer %}
#
# </body>
# </html>
#
# ```

# %% [markdown]
# 📁home.html
#
# ---
#
# ```html
#
# {% extends 'core/base.html' %}
#
# {% load django_bootstrap5 %}
#
# {% block title %}Home{% endblock title %}
#
# {% block hero %}
# <h2>Hero Section</h2>
# {% endblock hero %}
#
# {% block content %}
# <h1>Home Page</h1>
# <!-- way 1 to add bootstrap tags -->
# {% bootstrap_button button_type="submit" content="OK" %}
# {% bootstrap_button button_type="reset" content="Cancel" %}
#
# <!-- Way 2 to add bootstrap tags -->
# <button type="button" class="btn btn-primary">Primary</button>
# <button type="button" class="btn btn-secondary">Secondary</button>
# <button type="button" class="btn btn-success">Success</button>
# <button type="button" class="btn btn-danger">Danger</button>
# <button type="button" class="btn btn-warning">Warning</button>
# <button type="button" class="btn btn-info">Info</button>
# <button type="button" class="btn btn-light">Light</button>
# <button type="button" class="btn btn-dark">Dark</button>
#
# <button type="button" class="btn btn-link">Link</button>
# {% endblock content %}
#
# {% block footer %}This is Home Footer{% endblock footer %}
#
# ```

# %% [markdown]
# ## Video-19 (ch18): Setup Tailwind CSS with Django
# ---
# ---

# %% [markdown]
# **1. Adding Tailwind css using python command (without CLI):**
#
# [Tailwind Python Package Link](https://django-tailwind.readthedocs.io/en/latest/)
#
# [Tailwind Docs Link](https://tailwindcss.com/)
#
# - Project structure is similar
# - Go to Installation and follow the instructions
# - Go to the Project folder in command prompt
# - Install Tailwind: `pip install django-tailwind`
# - For auto reload install: `pip install "django-tailwind[cookiecutter,honcho,reload]"`
# - Then go to project's settings.py file and do the following:
#
# ```python
#
# INSTALLED_APPS = [
#     ...
#     'tailwind',
#     'core',
#     'course',
# ]
#
# ```
#
# - Create a Tailwind CSS compatible Django app: `python manage.py tailwind init`
# - A theme named application will be created add it in the settings.py file
# - Register the generated 'theme' app by adding the following line to settings.py
# - And add some extra command for settings
#
# ```python
#
# INSTALLED_APPS = [
#     ...
#     'tailwind',
#     'theme',
#     'django_browser_reload',
#     'core',
#     'course',
# ]
#
# TAILWIND_APP_NAME = "theme"
#
# INTERNAL_IPS = [
#     "127.0.0.1",
# ]
#
# NPM_BIN_PATH = 'npm.cmd'
#
# MIDDLEWARE = [
#     ...
#     'django_browser_reload.middleware.BrowserReloadMiddleware',
# ]
#
# ```
# - Install Tailwind CSS dependencies: `python manage.py tailwind install`
# - Than go to inner project's `urls.py` file and add the path: `path("__reload__/", include("django_browser_reload.urls")),`
# - Run Django server: `python manage.py runserver`
# - In another command prompt run this command for continuous monitoring: `python manage.py tailwind start`
#
# - For Production run this command: `python manage.py tailwind build`

# %% [markdown]
# 📁base.html
#
# ---
#
# ```html
#
# <!DOCTYPE html>
# {% load static %}
#
# <!-- Add this to set tailwind css in any templates -->
# {% load static tailwind_tags %}
#
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>{% block title %} {% endblock title %}</title>
#     {% tailwind_css %}
#
#     {% block corecss %}<link rel="stylesheet" href="{% static 'core/css/style.css' %}">{% endblock corecss %}
# </head>
# <body>
#     <ul>
#         <li>Home</li>
#         <li>Django</li>
#         <li>Python</li>
#     </ul>
#     {% block hero %}{% endblock hero %}
#
#     {% block content %}{% endblock content %}
#
#     {% block footer %}This is Footer{% endblock footer %}
#
#     <!-- Adding bootstrap using cdn link -->
#     <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.3.8/dist/js/bootstrap.bundle.min.js" integrity="sha384-FKyoEForCGlyvwx9Hj09JcYn3nv7wiPVlz7YYwJrWVcXK/BmnVDxM+D2scQbITxI" crossorigin="anonymous"></script>
# </body>
# </html>
#
# ```

# %% [markdown]
# 📁home.html
#
# ---
#
# ```html
#
# {% extends 'core/base.html' %}
#
# {% block title %}Home{% endblock title %}
#
# {% block hero %}
# <h2>Hero Section</h2>
# {% endblock hero %}
#
# {% block content %}
# <!-- Adding tailwind style -->
# <h1 class="bg-orange-400">Home Page</h1>
#
# <button type="button" class="btn btn-link">Link</button>
# {% endblock content %}
#
# {% block footer %}This is Home Footer{% endblock footer %}
#
# ```

# %% [markdown]
# ## Video-20 (ch19): Django 5 with Tailwind CSS CLI
# ---
# ---

# %% [markdown]
# **Adding Tailwind css using CLI:(not working)**
#
# [Tailwind css Docs Link](https://tailwindcss.com/)
#
# - Go to this link
# - Click get started
# - Click Tailwind CLI
# - Node js must be installed in the system, check version if installed: `node --version`
# - create a folder named `z_dev` in the outer project folder: `mkdir z_dev`
# - Then go to z_dev folder: `cd z_dev`
# - Here run the command: `npm init -y`
# - Now install tailwind CSS: `npm install tailwindcss @tailwindcss/cli`
# - We will add this z_dev folder in .gitignore file
# - Create `input.css` file in z_dev/src folder
# - Add the code in input.css file: `@import "tailwindcss";`
# - Go to z_dev/package.json file and add the dev code like followings:
#
# ```json
#
# "scripts": {
#     "test": "echo \"Error: no test specified\" && exit 1",
#     "dev": "npx @tailwindcss/cli -i ./src/input.css -o ../core/static/core/css/main.css --watch",
#     "prod": "npx @tailwindcss/cli -i ./src/input.css -o ../core/static/core/css/main.css --minify"
#   },
#
# ```
#
# - We need to run two terminal
# - At this time if we run the code it will generate unnecessary code in output main.css file
# - so we add the following code to z_dev/input.css file
#
# ```css
#
# @import "tailwindcss" source(none);
# @source "../templates/**/*.html";
# @source "../**/templates/**/*.html";
#
# ```
#
# - In first command prompt at folder => ch19\z_dev> `npm run dev`
# - In second command at project folder => ch19> `python manage.py runserver`

# %% [markdown]
# 📁base.html
#
# ---
#
# ```html
#
# <!DOCTYPE html>
# {% load static %}
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>{% block title %} {% endblock title %}</title>
#     {% block corecss %}<link rel="stylesheet" href="{% static 'core/css/style.css' %}">{% endblock corecss %}
#
#     <link rel="stylesheet" href="{% static 'core/css/main.css' %}">
# </head>
# <body>
#     <ul>
#         <li>Home</li>
#         <li>Django</li>
#         <li>Python</li>
#     </ul>
#     {% block hero %}{% endblock hero %}
#
#     {% block content %}{% endblock content %}
#
#     {% block footer %}This is Footer{% endblock footer %}
# </body>
# </html>
#
# ```

# %% [markdown]
# 📁home.html
#
# ---
#
# ```html
#
#
# {% extends 'core/base.html' %}
#
# {% block title %}Home{% endblock title %}
#
# {% block hero %}
# <h2>Hero Section</h2>
# {% endblock hero %}
#
# {% block content %}
# <h1 class="bg-orange-400">Home Page</h1>
#
# <button type="button" class="btn btn-link">Link</button>
# {% endblock content %}
#
# {% block footer %}This is Home Footer{% endblock footer %}
#
# ```

# %% [markdown]
# ## Video-21 (ch20): Hyperlink url Tag
# ---
# ---

# %% [markdown]
# 📁ch20/urls.py
#
# ---
#
# ```python
#
# from django.contrib import admin
# from django.urls import path, include
#
# urlpatterns = [
#     path('admin/', admin.site.urls),
#     path('', include('core.urls')),
#     path('course/', include('course.urls')),
# ]
#
# ```
#
#
# 📁core/urls.py
#
# ---
#
# ```python
#
# from django.urls import path
# from .views import home, about
#
# urlpatterns = [
#     path('', home, name='home'),
#     path('about/', about, name='about'),
# ]
#
# ```
#
# 📁course/urls.py
#
# ---
#
# ```python
#
# from django.urls import path
# from .views import learn_django, learn_python
#
# urlpatterns = [
#     path('dj/', learn_django, name='django'),
#     path('py/', learn_python, name='python'),
# ]
#
# ```

# %% [markdown]
# 📁base.html
#
# ---
#
# ```html
#
# <!DOCTYPE html>
# {% load static %}
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>{% block title %}{% endblock title %}</title>
#     <link rel="stylesheet" href="{% static 'core/css/style.css' %}">
# </head>
# <body>
#     <nav>
#         <ul>
#             <li><a href="{}">Home</a></li>
#             <li><a href="/about">About</a></li>
#             <li><a href="/course/dj">Django</a></li>
#             <li><a href="/course/py">Python</a></li>
#         </ul>
#         <hr>
#         <ul>
#             <li><a href="{% url 'home' %}">Home</a></li>
#             <li><a href="{% url 'about' %}">About</a></li>
#             <li><a href="{% url 'django' %}">Django</a></li>
#             <li><a href="{% url 'python' %}">Python</a></li>
#
#             {% url 'python' as py %}
#             <li><a href="{{py}}">Python as py</a></li>
#         </ul>
#     </nav>
#     {% block hero %}{% endblock hero %}
#
#     {% block content %}{% endblock content %}
#
#     {% block footer %}This is Footer{% endblock footer %}
# </body>
# </html>
#
# ```

# %% [markdown]
# ## Video-22 (ch21): Template inside Template using Include Tag
# ---
# ---

# %% [markdown]
# **Project Folder Structure:**
# - ch21
#     - core
#         - templates
#             - core
#                 - components
#                     - hero.html
#                     - navbar.html
#                     - list.html
#                 - about.html
#                 - base.html
#                 - home.html

# %% [markdown]
# 📁core/views.py
#
# ---
#
# ```python
#
# from django.shortcuts import render
#
# def home(req):
#     return render(req, 'core/home.html',{'list_element': 'Python'})
#
# def about(req):
#     return render(req, 'core/about.html')
#
# ```

# %% [markdown]
# 📁core/templates/core/components/hero.html
#
# ---
#
# ```html
#
# <h2>Hero Section Title</h2>
# <h3>Hero Section Sub Title</h3>
# <h4>Hero Section Text</h4>
#
# ```
#
# 📁core/templates/core/components/navbar.html
#
# ---
#
# ```html
#
# <nav>
#     <ul>
#         <li><a href="{% url 'home' %}">Home</a></li>
#         <li><a href="{% url 'about' %}">About</a></li>
#         <li><a href="{% url 'django' %}">Django</a></li>
#         <li><a href="{% url 'python' %}">Python</a></li>
#     </ul>
# </nav>
#
# ```
#
# 📁core/templates/core/components/list.html
#
# ---
#
# ```html
#
# <ul>
#     <li>{{list_element}}</li>
#     <li>{{lang}}</li>
#     <li>Django</li>
#     <li>Java</li>
# </ul>
#
# ```

# %% [markdown]
# 📁core/templates/core/base.html
#
# ---
#
# ```html
#
# <!DOCTYPE html>
# {% load static %}
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>{% block title %}{% endblock title %}</title>
#     <link rel="stylesheet" href="{% static 'core/css/style.css' %}">
# </head>
# <body>
#     {% include 'core/components/navbar.html' %}
#
#     {% block hero %}{% endblock hero %}
#
#     {% block content %}{% endblock content %}
#
#     {% block footer %}This is Footer{% endblock footer %}
# </body>
# </html>
#
# ```

# %% [markdown]
# 📁core/templates/core/home.html
#
# ---
#
# ```html
#
# {% extends 'core/base.html' %}
#
# {% block title %}Home{% endblock title %}
#
# {% block hero %}
# {% include 'core/components/hero.html' %}
# {% endblock hero %}
#
# {% block content %}
# <h1>Home Page</h1>
#
# {% include "core/components/list.html" %}
# <hr>
# {% include "core/components/list.html" with list_element='JavaScript' %}
# <hr>
# {% include "core/components/list.html" with lang='JavaScript' %}
# <hr>
# {% include "core/components/list.html" with lang='JavaScript' only %}
#
# {% endblock content %}
#
# {% block footer %}This is Home Footer{% endblock footer %}
#
# ```

# %% [markdown]
# 📁core/templates/core/home.html
#
# ---
#
# ```html
#
# {% extends 'core/base.html' %}
#
# {% block title %}About{% endblock title %}
#
# {% block hero %}
# {% include 'core/components/hero.html' %}
# {% endblock hero %}
#
# {% block content %}
# <h1>About Page</h1>
#
# {% include "core/components/list.html" %}
# <hr>
# {% include "core/components/list.html" with list_element='JavaScript' %}
# <hr>
# {% include "core/components/list.html" with lang='JavaScript' %}
# <hr>
# {% include "core/components/list.html" with lang='JavaScript' only %}
#
# {% endblock content %}
#
# {% block footer %}This is Home Footer{% endblock footer %}
#
# ```
