# %% [markdown]
# ## Video-98 (ch91): Buildin Authentication in Django 5
# ---
# ---

# %% [markdown]
# 📂ch91/urls.py
#
# ---
# ```python
#
# from django.contrib import admin
# from django.urls import path, include
#
# urlpatterns = [
#     path('admin/', admin.site.urls),
#     path('accounts/', include('django.contrib.auth.urls'))
# ]
#
# ```

# %% [markdown]
# http://127.0.0.1:8000/accounts/login/
#
# registration/login.html
#
# Create registration application
#
# Inside registration application create folders templates/registration/login.html
#
#
#
# ```html
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
# </head>
# <body>
#     <form action="" method="post">
#         {{form.as_p}}
#         <input type="submit" value="Login" >
#     </form>
# </body>
# </html>
# ```

# %% [markdown]
# ## Video-99 (ch91): Async Class based View in django 5
# ---
# ---
